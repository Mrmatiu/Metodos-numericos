# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrmatiu/Metodos-numericos/blob/master/numericos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Metodo delta de aitken

# %%
### Metodo de steffensen

# %%
### Metodo modificando de aitken

import scipy.integrate as spi
import numpy as np
import math  
from numpy import ndarray

def funcion_1(x): return math.sqrt(10/(x+4));
def funcion_2(x): return (2-math.exp(x) + x**2)/3;
def funcion_3(x): return (math.sin(x)+math.cos(x))/2;

def main():
  po = 0.5;
  p1 = 0;
  p2 = 0;
  pñ = 0;
  tol = 1e-10;
  i = 1;
  condicion = 1;
  print(" Metodo modificado de Aitken");
  print(" |  n  |       Pn       |    Pn-1     |");
  while condicion == 1:
    p1 = funcion_2(po);
    p2 = funcion_2(p1);
    pñ = p2 - ((p2 - p1)**2)/(p2 -2*p1 +po);
    q = funcion_2(pñ);
    valor_absoluto = abs(pñ - q);
    z = ' | ' + str(i) + ' | ' + str('%.6f'%pñ) +' | ' +str('%.6f'%q)+ ' | ';
    if valor_absoluto < tol:
      print(' \n La raiz es ' + str(pñ));
      condicion == 0;
    po = p1;
    p1 = p2;

  
if __name__ == "__main__":
   
    main()
# Out:
#  Metodo modificado de Aitken
#  |  n  |       Pn       |    Pn-1     |
#
#  La raiz es 0.25753028544757317
#
#  La raiz es 0.25753028544038037
#
#  La raiz es 0.25753028543989576
#
#  La raiz es 0.2575302854398631
#
#  La raiz es 0.2575302854398609
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.25753028543986073
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.25753028543986073
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.25753028543986073
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.25753028543986073
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.2575302854398608
#
#  La raiz es 0.25753028543986073
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-41-c5900804b246> in <module>()
#      35 if __name__ == "__main__":
#      36
# ---> 37     main()
#      38
#
# <ipython-input-41-c5900804b246> in main()
#      22     p1 = funcion_2(po);
#      23     p2 = funcion_2(p1);
# ---> 24     pñ = p2 - ((p2 - p1)**2)/(p2 -2*p1 +po);
#      25     q = funcion_2(pñ);
#      26     valor_absoluto = abs(pñ - q);
#
# ZeroDivisionError: float division by zero

# %%
### Metodo de la secante


import scipy.integrate as spi
import numpy as np
import math  
from numpy import ndarray

def funcion_1(x): return x**3 + 4*x**2 -10;
def funcion_2(x): return math.log(x-1) + math.cos(x-1);
def funcion_3(x): return np.exp(x) + -x**2 + 2*math.cos(x)-6;

def main():
  pn_inferior = 1.3;
  pn = 1.5;
  pn_superior = 0;
  tol = 1e-3;
  i = 1;
  condicion = 1;
  print(" Metodo de la secante");
  print(" |  n  |       Pn+1       |    Pn    |   Pn-1  |         f(Pn)         |       |f(Pn)|       |");
  while condicion == 1:
    pn_superior = pn -((pn - pn_inferior)/(funcion_2(pn) - funcion_2(pn_inferior)) )*funcion_2(pn);
    fp = funcion_2(pn_superior);
    fp_absoluto = abs(fp);
    p_abosoluto = abs(pn_superior-pn);
    z = ' | ' + str(i) + ' | ' + str('%.6f'%pn_superior) +' | ' + str('%.6f'%pn) + ' | ' +str('%.6f'%pn_inferior)+ ' | ' +str('%.7f'%fp)+ ' | ' + str('%.7f'%fp_absoluto);
    print(z);
    if p_abosoluto < tol:
      print(' \n La raiz es ' + str(pn));
      condicion = 0;
    i = i+1;
    pn_inferior = pn;
    pn = pn_superior;
    
    
  
if __name__ == "__main__":
   
    main()

# %%
### Metodo de la biseccion.

import scipy.integrate as spi
import numpy as np

def funcion(x):
  p = 0;
  #p = np.exp(x) - x**2 + 2*np.cos(x) - 6;
  #p = np.log(x-1) + cos(x-1);
  p = x**3 + 4*(x**2) - 10;
  return p;


def main():
  a = 1;
  b = 2;
  tol = 1e-4;
  po = 0.00000;
  fp = 0;
  i = 1;
  condicion = 0;
  print(" Metodo de la bisección ");
  print(" | n |    Pn    |   f(Pn)   |   [f(Pn)]  |");
  while condicion <= 0:
    po = (a+b)/2;
    fp = funcion(po);
    valor_absoluto = abs(fp)
    s = ' | ' + str(i) + ' | ' + str('%.6f'%po) + ' | ' + str('%.6f'%fp) + ' | ' + str('%.6f'%valor_absoluto) + ' | ';
    print (s);
    if abs(fp) <= tol:
      print("\nLa raiz de la funcion es " + repr(po));
      condicion = 1;
    else:
      if (funcion(po)*funcion(a)) < 0:
        b = po;
      if (funcion(po)*funcion(b)) < 0:
        a = po;
    i = i +1
    
  
if __name__ == "__main__":
   
    main()

# %%
### Metodo de iteracion punto fijo.


import scipy.integrate as spi
import numpy as np
import math  
from numpy import ndarray

def funcion_1(x): return x - (x**3) - 4*(x**2) +10;
def funcion_2(x): return math.sqrt((10/x)-4*x);
def funcion_3(x): return 0.5*math.sqrt(10-(x**3));
def funcion_4(x): return sqrt(10/(4+x));
def funcion_5(x): return x - ((x**3) + 4*(x**2) - 10)/(3*(x**2)+8*x);



def main():
  po = 1.1;
  p = 0;
  err = 1;
  tol = 1e-10;
  i = 1;
  print(" Metodo de iteracion de punto fijo");
  print(" | n |    Pn    |   Pn-1   |  [Pn-Pn-1] |");
  s = ' | 0 | ' + str('%.6f'%p) + ' |  -----   | ' + '  ------   | ';  
  print (s);
  p = funcion_5(po);
  while err > tol:
    err = abs(p - po);
    po = p;
    p = funcion_5(po);
    z = ' | ' + str(i) + ' | ' + str('%.6f'%p) +' | ' +str('%.6f'%po)+ ' | ' +str('%.7f'%err)+ ' | ';
    print(z);
    i = i+1;
    
    
  
if __name__ == "__main__":
   
    main()
# Out:
#  Metodo de iteracion de punto fijo
#  | n |    Pn    |   Pn-1   |  [Pn-Pn-1] |
#  | 0 | 0.000000 |  -----   |   ------   |
#  | 1 | 1.366101 | 1.408045 | 0.3080451 |
#  | 2 | 1.365230 | 1.366101 | 0.0419437 |
#  | 3 | 1.365230 | 1.365230 | 0.0008710 |
#  | 4 | 1.365230 | 1.365230 | 0.0000004 |
#  | 5 | 1.365230 | 1.365230 | 0.0000000 |

# %%
### Metodo de Newton - Raphson

import scipy.integrate as spi
import numpy as np
from numpy import ndarray

def funcion(x):
  float p;
  p = np.log(x-1) + np.cos(x-1);
  return p;

def derivada_funcion(x):
  float q;
  q = 1/(x-1) - np.sin(x-1);
  return q;

p = ndarray((100,),int)
fp = ndarray((100,),int)
int i = 1;
p[i-1] = 1.5
float tol = 1e-5;
int a = 1;
  print(" Metodo de Newton - Raphson ");
  print("\n");
  print(" | n |   Pn   |    f(Pn)   |   |f(Pn)|    |");
  while a == 1;
